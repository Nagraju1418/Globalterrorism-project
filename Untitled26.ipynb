# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\91703\\Downloads\\Modified_global.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2276 entries, 0 to 2275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   eventid          2276 non-null   float64
#  1   iyear            2276 non-null   int64
#  2   imonth           2276 non-null   int64
#  3   iday             2276 non-null   int64
#  4   country_txt      2276 non-null   object
#  5   region_txt       2276 non-null   object
#  6   attacktype1_txt  2276 non-null   object
#  7   target1          2264 non-null   object
#  8   nkill            2081 non-null   float64
#  9   nwound           1948 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 177.9+ KB

# %%
print(data.head())
# Out:
#         eventid  iyear  imonth  iday         country_txt  \
# 0  1.970000e+11   1970       7     2  Dominican Republic
# 1  1.970000e+11   1970       0     0              Mexico
# 2  1.970010e+11   1970       1     0         Philippines
# 3  1.970010e+11   1970       1     0              Greece
# 4  1.970010e+11   1970       1     0               Japan
#
#                     region_txt                 attacktype1_txt  \
# 0  Central America & Caribbean                   Assassination
# 1                North America     Hostage Taking (Kidnapping)
# 2               Southeast Asia                   Assassination
# 3               Western Europe               Bombing/Explosion
# 4                    East Asia  Facility/Infrastructure Attack
#
#                    target1  nkill  nwound
# 0             Julio Guzman    1.0     0.0
# 1  Nadine Chaval, daughter    0.0     0.0
# 2                 Employee    1.0     0.0
# 3             U.S. Embassy    NaN     NaN
# 4           U.S. Consulate    NaN     NaN

# %%
data['Year'] = pd.to_datetime(data['iyear'], format='%Y')
yearly_attacks = data['Year'].dt.year.value_counts().sort_index()

# %%
plt.figure(figsize=(12, 6))
yearly_attacks.plot(kind='line', marker='o')
plt.title('Global Terrorism Trends Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.grid(True)
plt.show()

# %%
# Analyze types of attacks
attack_types = data['attacktype1_txt'].value_counts()

# %%
# Plot the most common types of attacks
plt.figure(figsize=(10, 6))
attack_types.plot(kind='bar')
plt.title('Most Common Types of Terrorist Attacks')
plt.xlabel('Attack Type')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=90)
plt.show()

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("example").getOrCreate()

# Read data from a source (e.g., CSV file)
df = spark.read.csv(r"C:\Users\91703\Downloads\Modified_global.csv", header=True, inferSchema=True)

# Now you can work with the 'df' DataFrame
df.printSchema()
# Out:
# root
#  |-- eventid: double (nullable = true)
#  |-- iyear: integer (nullable = true)
#  |-- imonth: integer (nullable = true)
#  |-- iday: integer (nullable = true)
#  |-- country_txt: string (nullable = true)
#  |-- region_txt: string (nullable = true)
#  |-- attacktype1_txt: string (nullable = true)
#  |-- target1: string (nullable = true)
#  |-- nkill: integer (nullable = true)
#  |-- nwound: integer (nullable = true)

# %%
df.show()
# Out:
# +----------+-----+------+----+------------------+--------------------+--------------------+--------------------+-----+------+
# |   eventid|iyear|imonth|iday|       country_txt|          region_txt|     attacktype1_txt|             target1|nkill|nwound|
# +----------+-----+------+----+------------------+--------------------+--------------------+--------------------+-----+------+
# |   1.97E11| 1970|     7|   2|Dominican Republic|Central America &...|       Assassination|        Julio Guzman|    1|     0|
# |   1.97E11| 1970|     0|   0|            Mexico|       North America|Hostage Taking (K...|Nadine Chaval, da...|    0|     0|
# |1.97001E11| 1970|     1|   0|       Philippines|      Southeast Asia|       Assassination|            Employee|    1|     0|
# |1.97001E11| 1970|     1|   0|            Greece|      Western Europe|   Bombing/Explosion|        U.S. Embassy| null|  null|
# |1.97001E11| 1970|     1|   0|             Japan|           East Asia|Facility/Infrastr...|      U.S. Consulate| null|  null|
# |1.97001E11| 1970|     1|   1|     United States|       North America|       Armed Assault|Cairo Police Head...|    0|     0|
# |1.97001E11| 1970|     1|   2|           Uruguay|       South America|       Assassination|Juan Maria de Luc...|    0|     0|
# |1.97001E11| 1970|     1|   2|     United States|       North America|   Bombing/Explosion|     Edes Substation|    0|     0|
# |1.97001E11| 1970|     1|   2|     United States|       North America|Facility/Infrastr...|R.O.T.C. offices ...|    0|     0|
# |1.97001E11| 1970|     8|   3|     United States|       North America|Facility/Infrastr...|Selective Service...|    0|     0|
# |1.97001E11| 1970|     1|   1|     United States|       North America|   Bombing/Explosion|Badger Army ammo ...|    0|     0|
# |1.97001E11| 1970|     1|   6|     United States|       North America|Facility/Infrastr...|Army Recruiting S...|    0|     0|
# |1.97001E11| 1970|     1|   8|             Italy|      Western Europe|           Hijacking|Flight 802 Boeing...|    0|     0|
# |1.97001E11| 1970|    12|   9|     United States|       North America|Facility/Infrastr...|Packard Propertie...|    0|     0|
# |1.97001E11| 1970|     1|   9|     United States|       North America|Facility/Infrastr...|       Baker's Store|    0|     0|
# |1.97001E11| 1970|     5|  10|East Germany (GDR)|      Eastern Europe|   Bombing/Explosion|Jurists Ball (Pal...| null|  null|
# |1.97001E11| 1970|     5|  11|          Ethiopia|  Sub-Saharan Africa|             Unknown|             Soldier|    1|     0|
# |1.97001E11| 1970|     5|  12|     United States|       North America|   Bombing/Explosion|James Madison Hig...|    0|     0|
# |1.97001E11| 1970|     5|  12|     United States|       North America|   Bombing/Explosion|General Electric ...|    0|     0|
# |1.97001E11| 1970|     5|  13|     United States|       North America|Facility/Infrastr...|Fuson's Departmen...|    0|     0|
# +----------+-----+------+----+------------------+--------------------+--------------------+--------------------+-----+------+
# only showing top 20 rows

# %%
df.head(20)
# Out:
# [Row(eventid=197000000000.0, iyear=1970, imonth=7, iday=2, country_txt='Dominican Republic', region_txt='Central America & Caribbean', attacktype1_txt='Assassination', target1='Julio Guzman', nkill=1, nwound=0),
#  Row(eventid=197000000000.0, iyear=1970, imonth=0, iday=0, country_txt='Mexico', region_txt='North America', attacktype1_txt='Hostage Taking (Kidnapping)', target1='Nadine Chaval, daughter', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=0, country_txt='Philippines', region_txt='Southeast Asia', attacktype1_txt='Assassination', target1='Employee', nkill=1, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=0, country_txt='Greece', region_txt='Western Europe', attacktype1_txt='Bombing/Explosion', target1='U.S. Embassy', nkill=None, nwound=None),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=0, country_txt='Japan', region_txt='East Asia', attacktype1_txt='Facility/Infrastructure Attack', target1='U.S. Consulate', nkill=None, nwound=None),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=1, country_txt='United States', region_txt='North America', attacktype1_txt='Armed Assault', target1='Cairo Police Headquarters', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=2, country_txt='Uruguay', region_txt='South America', attacktype1_txt='Assassination', target1='Juan Maria de Lucah/Chief of Directorate of info. and intell.', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=2, country_txt='United States', region_txt='North America', attacktype1_txt='Bombing/Explosion', target1='Edes Substation', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=2, country_txt='United States', region_txt='North America', attacktype1_txt='Facility/Infrastructure Attack', target1='R.O.T.C. offices at University of Wisconsin, Madison', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=8, iday=3, country_txt='United States', region_txt='North America', attacktype1_txt='Facility/Infrastructure Attack', target1='Selective Service Headquarters in Madison Wisconsin', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=1, country_txt='United States', region_txt='North America', attacktype1_txt='Bombing/Explosion', target1='Badger Army ammo depot.', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=6, country_txt='United States', region_txt='North America', attacktype1_txt='Facility/Infrastructure Attack', target1='Army Recruiting Station, Denver Colorado', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=8, country_txt='Italy', region_txt='Western Europe', attacktype1_txt='Hijacking', target1='Flight 802 Boeing 707', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=12, iday=9, country_txt='United States', region_txt='North America', attacktype1_txt='Facility/Infrastructure Attack', target1='Packard Properties building of Detroit Michigan', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=1, iday=9, country_txt='United States', region_txt='North America', attacktype1_txt='Facility/Infrastructure Attack', target1="Baker's Store", nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=5, iday=10, country_txt='East Germany (GDR)', region_txt='Eastern Europe', attacktype1_txt='Bombing/Explosion', target1='Jurists Ball (Palais au Frankturm)', nkill=None, nwound=None),
#  Row(eventid=197001000000.0, iyear=1970, imonth=5, iday=11, country_txt='Ethiopia', region_txt='Sub-Saharan Africa', attacktype1_txt='Unknown', target1='Soldier', nkill=1, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=5, iday=12, country_txt='United States', region_txt='North America', attacktype1_txt='Bombing/Explosion', target1='James Madison High School', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=5, iday=12, country_txt='United States', region_txt='North America', attacktype1_txt='Bombing/Explosion', target1='General Electric factory in Rio Grande Puerto Rico', nkill=0, nwound=0),
#  Row(eventid=197001000000.0, iyear=1970, imonth=5, iday=13, country_txt='United States', region_txt='North America', attacktype1_txt='Facility/Infrastructure Attack', target1="Fuson's Department Store, Seattle Washington", nkill=0, nwound=0)]

# %%
num_columns = len(df.columns)
print("Number of columns:", num_columns)
# Out:
# Number of columns: 10
