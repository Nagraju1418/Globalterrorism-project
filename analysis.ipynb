# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\91703\Downloads\Modified_global.csv")
df=pd.DataFrame(data)
print("DATA IS IMPORTED")
df.head()
# Out:
# DATA IS IMPORTED
#         eventid  iyear  imonth  iday         country_txt  \
# 0  1.970000e+11   1970       7     2  Dominican Republic
# 1  1.970000e+11   1970       0     0              Mexico
# 2  1.970010e+11   1970       1     0         Philippines
# 3  1.970010e+11   1970       1     0              Greece
# 4  1.970010e+11   1970       1     0               Japan
#
#                     region_txt                 attacktype1_txt  \
# 0  Central America & Caribbean                   Assassination
# 1                North America     Hostage Taking (Kidnapping)
# 2               Southeast Asia                   Assassination
# 3               Western Europe               Bombing/Explosion
# 4                    East Asia  Facility/Infrastructure Attack
#
#                    target1  nkill  nwound
# 0             Julio Guzman    1.0     0.0
# 1  Nadine Chaval, daughter    0.0     0.0
# 2                 Employee    1.0     0.0
# 3             U.S. Embassy    NaN     NaN
# 4           U.S. Consulate    NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2276 entries, 0 to 2275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   eventid          2276 non-null   float64
#  1   iyear            2276 non-null   int64
#  2   imonth           2276 non-null   int64
#  3   iday             2276 non-null   int64
#  4   country_txt      2276 non-null   object
#  5   region_txt       2276 non-null   object
#  6   attacktype1_txt  2276 non-null   object
#  7   target1          2264 non-null   object
#  8   nkill            2081 non-null   float64
#  9   nwound           1948 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 177.9+ KB

# %%
df.shape
# Out:
# (2276, 10)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'attacktype1_txt', 'target1', 'nkill', 'nwound'],
#       dtype='object')

# %%
df=df[["iyear", "imonth","iday","country_txt","region_txt","eventid","attacktype1_txt","target1","nkill","nwound"]]
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#         eventid                 attacktype1_txt                  target1  \
# 0  1.970000e+11                   Assassination             Julio Guzman
# 1  1.970000e+11     Hostage Taking (Kidnapping)  Nadine Chaval, daughter
# 2  1.970010e+11                   Assassination                 Employee
# 3  1.970010e+11               Bombing/Explosion             U.S. Embassy
# 4  1.970010e+11  Facility/Infrastructure Attack           U.S. Consulate
#
#    nkill  nwound
# 0    1.0     0.0
# 1    0.0     0.0
# 2    1.0     0.0
# 3    NaN     NaN
# 4    NaN     NaN

# %%
df.rename (columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country", "region_txt":"Region","attacktype1_txt":"Attack Type","nkill":"Killed","nwound":"Nwound"},inplace=True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#         eventid                     Attack Type                  target1  \
# 0  1.970000e+11                   Assassination             Julio Guzman
# 1  1.970000e+11     Hostage Taking (Kidnapping)  Nadine Chaval, daughter
# 2  1.970010e+11                   Assassination                 Employee
# 3  1.970010e+11               Bombing/Explosion             U.S. Embassy
# 4  1.970010e+11  Facility/Infrastructure Attack           U.S. Consulate
#
#    Killed  Nwound
# 0     1.0     0.0
# 1     0.0     0.0
# 2     1.0     0.0
# 3     NaN     NaN
# 4     NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2276 entries, 0 to 2275
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         2276 non-null   int64
#  1   Month        2276 non-null   int64
#  2   Day          2276 non-null   int64
#  3   Country      2276 non-null   object
#  4   Region       2276 non-null   object
#  5   eventid      2276 non-null   float64
#  6   Attack Type  2276 non-null   object
#  7   target1      2264 non-null   object
#  8   Killed       2081 non-null   float64
#  9   Nwound       1948 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 177.9+ KB

# %%
df.isnull().sum()
# Out:
# Year             0
# Month            0
# Day              0
# Country          0
# Region           0
# eventid          0
# Attack Type      0
# target1         12
# Killed         195
# Nwound         328
# dtype: int64

# %%
df["Nwound"]=df["Nwound"].fillna(0)
df["Nwound"]=df["Nwound"].fillna(0)

# %%
df.describe()
# Out:
#               Year        Month          Day       eventid       Killed  \
# count  2276.000000  2276.000000  2276.000000  2.276000e+03  2081.000000
# mean   1993.412566     4.914763    13.284710  1.993470e+11     2.097069
# std      14.299829     3.368338     8.918816  1.432858e+09     7.395047
# min    1970.000000     0.000000     0.000000  1.970000e+11     0.000000
# 25%    1981.000000     2.000000     6.000000  1.981100e+11     0.000000
# 50%    1992.000000     4.000000    11.000000  1.992110e+11     0.000000
# 75%    2006.000000     7.000000    21.000000  2.006020e+11     1.000000
# max    2017.000000    12.000000    31.000000  2.017120e+11   200.000000
#
#             Nwound
# count  2276.000000
# mean      2.368629
# std       9.516942
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max     200.000000

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'eventid', 'Attack Type',
#        'target1', 'Killed', 'Nwound'],
#       dtype='object')

# %%
yk=df[["Year",'Killed']].groupby("Year").sum()
yk.head()
# Out:
#       Killed
# Year
# 1970     4.0
# 1971    13.0
# 1972    41.0
# 1973    45.0
# 1974    18.0

# %%
df.head(30)
# Out:
#     Year  Month  Day             Country                       Region  \
# 0   1970      7    2  Dominican Republic  Central America & Caribbean
# 1   1970      0    0              Mexico                North America
# 2   1970      1    0         Philippines               Southeast Asia
# 3   1970      1    0              Greece               Western Europe
# 4   1970      1    0               Japan                    East Asia
# 5   1970      1    1       United States                North America
# 6   1970      1    2             Uruguay                South America
# 7   1970      1    2       United States                North America
# 8   1970      1    2       United States                North America
# 9   1970      8    3       United States                North America
# 10  1970      1    1       United States                North America
# 11  1970      1    6       United States                North America
# 12  1970      1    8               Italy               Western Europe
# 13  1970     12    9       United States                North America
# 14  1970      1    9       United States                North America
# 15  1970      5   10  East Germany (GDR)               Eastern Europe
# 16  1970      5   11            Ethiopia           Sub-Saharan Africa
# 17  1970      5   12       United States                North America
# 18  1970      5   12       United States                North America
# 19  1970      5   13       United States                North America
# 20  1970      5   14       United States                North America
# 21  1970      1   15             Uruguay                South America
# 22  1970      1   19       United States                North America
# 23  1970      1   19       United States                North America
# 24  1970      1   19       United States                North America
# 25  1970      1   20           Guatemala  Central America & Caribbean
# 26  1970      1   21         Philippines               Southeast Asia
# 27  1970     11   22           Venezuela                South America
# 28  1970      1   22       United States                North America
# 29  1970      1   25       United States                North America
#
#          eventid                     Attack Type  \
# 0   1.970000e+11                   Assassination
# 1   1.970000e+11     Hostage Taking (Kidnapping)
# 2   1.970010e+11                   Assassination
# 3   1.970010e+11               Bombing/Explosion
# 4   1.970010e+11  Facility/Infrastructure Attack
# 5   1.970010e+11                   Armed Assault
# 6   1.970010e+11                   Assassination
# 7   1.970010e+11               Bombing/Explosion
# 8   1.970010e+11  Facility/Infrastructure Attack
# 9   1.970010e+11  Facility/Infrastructure Attack
# 10  1.970010e+11               Bombing/Explosion
# 11  1.970010e+11  Facility/Infrastructure Attack
# 12  1.970010e+11                       Hijacking
# 13  1.970010e+11  Facility/Infrastructure Attack
# 14  1.970010e+11  Facility/Infrastructure Attack
# 15  1.970010e+11               Bombing/Explosion
# 16  1.970010e+11                         Unknown
# 17  1.970010e+11               Bombing/Explosion
# 18  1.970010e+11               Bombing/Explosion
# 19  1.970010e+11  Facility/Infrastructure Attack
# 20  1.970010e+11  Facility/Infrastructure Attack
# 21  1.970010e+11                   Armed Assault
# 22  1.970010e+11               Bombing/Explosion
# 23  1.970010e+11               Bombing/Explosion
# 24  1.970010e+11  Facility/Infrastructure Attack
# 25  1.970010e+11                   Assassination
# 26  1.970010e+11               Bombing/Explosion
# 27  1.970010e+11     Hostage Taking (Kidnapping)
# 28  1.970010e+11               Bombing/Explosion
# 29  1.970010e+11  Facility/Infrastructure Attack
#
#                                               target1  Killed  Nwound
# 0                                        Julio Guzman     1.0     0.0
# 1                             Nadine Chaval, daughter     0.0     0.0
# 2                                            Employee     1.0     0.0
# 3                                        U.S. Embassy     NaN     0.0
# 4                                      U.S. Consulate     NaN     0.0
# 5                           Cairo Police Headquarters     0.0     0.0
# 6   Juan Maria de Lucah/Chief of Directorate of in...     0.0     0.0
# 7                                     Edes Substation     0.0     0.0
# 8   R.O.T.C. offices at University of Wisconsin, M...     0.0     0.0
# 9   Selective Service Headquarters in Madison Wisc...     0.0     0.0
# 10                            Badger Army ammo depot.     0.0     0.0
# 11           Army Recruiting Station, Denver Colorado     0.0     0.0
# 12                              Flight 802 Boeing 707     0.0     0.0
# 13    Packard Properties building of Detroit Michigan     0.0     0.0
# 14                                      Baker's Store     0.0     0.0
# 15                 Jurists Ball (Palais au Frankturm)     NaN     0.0
# 16                                            Soldier     1.0     0.0
# 17                          James Madison High School     0.0     0.0
# 18  General Electric factory in Rio Grande Puerto ...     0.0     0.0
# 19       Fuson's Department Store, Seattle Washington     0.0     0.0
# 20                        Champaign Police Department     0.0     1.0
# 21                    Secondary School, Chemistry Lab     0.0     0.0
# 22  Liberal Arts and Garrand buildings, Seattle Un...     0.0     0.0
# 23  Air Force R.O.T.C. at the University of Washin...     0.0     0.0
# 24                                       Headquarters     0.0     0.0
# 25                          Bodyguard, British Consul     1.0     0.0
# 26                                          JUSMAG HQ     0.0     0.0
# 27                            Leon Jacobo Taurel, son     0.0     0.0
# 28                                                NaN     0.0     0.0
# 29  Building used as a meeting place for African A...     0.0     0.0
